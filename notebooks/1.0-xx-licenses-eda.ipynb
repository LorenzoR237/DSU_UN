# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))   # adds project root to sys.path

from src import config
import pandas as pd

licenses = pd.read_csv(config.LICENSES_RAW, low_memory=False)
